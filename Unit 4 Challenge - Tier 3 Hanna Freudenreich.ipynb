# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
import datetime as dt
# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
df = pd.DataFrame(properties)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            310 non-null    datetime64[ns]
#  1   City of London        311 non-null    object
#  2   Barking & Dagenham    311 non-null    object
#  3   Barnet                311 non-null    object
#  4   Bexley                311 non-null    object
#  5   Brent                 311 non-null    object
#  6   Bromley               311 non-null    object
#  7   Camden                311 non-null    object
#  8   Croydon               311 non-null    object
#  9   Ealing                311 non-null    object
#  10  Enfield               311 non-null    object
#  11  Greenwich             311 non-null    object
#  12  Hackney               311 non-null    object
#  13  Hammersmith & Fulham  311 non-null    object
#  14  Haringey              311 non-null    object
#  15  Harrow                311 non-null    object
#  16  Havering              311 non-null    object
#  17  Hillingdon            311 non-null    object
#  18  Hounslow              311 non-null    object
#  19  Islington             311 non-null    object
#  20  Kensington & Chelsea  311 non-null    object
#  21  Kingston upon Thames  311 non-null    object
#  22  Lambeth               311 non-null    object
#  23  Lewisham              311 non-null    object
#  24  Merton                311 non-null    object
#  25  Newham                311 non-null    object
#  26  Redbridge             311 non-null    object
#  27  Richmond upon Thames  311 non-null    object
#  28  Southwark             311 non-null    object
#  29  Sutton                311 non-null    object
#  30  Tower Hamlets         311 non-null    object
#  31  Waltham Forest        311 non-null    object
#  32  Wandsworth            311 non-null    object
#  33  Westminster           311 non-null    object
#  34  Unnamed: 34           0 non-null      float64
#  35  Inner London          311 non-null    object
#  36  Outer London          311 non-null    object
#  37  Unnamed: 37           0 non-null      float64
#  38  NORTH EAST            311 non-null    object
#  39  NORTH WEST            311 non-null    object
#  40  YORKS & THE HUMBER    311 non-null    object
#  41  EAST MIDLANDS         311 non-null    object
#  42  WEST MIDLANDS         311 non-null    object
#  43  EAST OF ENGLAND       311 non-null    object
#  44  LONDON                311 non-null    object
#  45  SOUTH EAST            311 non-null    object
#  46  SOUTH WEST            311 non-null    object
#  47  Unnamed: 47           0 non-null      float64
#  48  England               311 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(45)
# memory usage: 119.2+ KB

# %%
df.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %%
df.iloc[0,0]="ID"
df.head()
df.set_index(df.iloc[:,0], inplace=True)
df1=df.iloc[:,1:]
df1.index.name="Index"
df1
# Out:
#                     City of London Barking & Dagenham     Barnet     Bexley  \
# Index
# ID                       E09000001          E09000002  E09000003  E09000004
# 1995-01-01 00:00:00          91449            50460.2    93284.5    64958.1
# 1995-02-01 00:00:00        82202.8            51085.8    93190.2    64787.9
# 1995-03-01 00:00:00        79120.7              51269    92247.5    64367.5
# 1995-04-01 00:00:00        77101.2            53133.5    90762.9    64277.7
# ...                            ...                ...        ...        ...
# 2020-06-01 00:00:00         869929             299074     517266     340723
# 2020-07-01 00:00:00         785001             303701     521528     343385
# 2020-08-01 00:00:00         794881             304696     525762     348046
# 2020-09-01 00:00:00         768714             301170     535663     345461
# 2020-10-01 00:00:00         721490             308583     536263     344254
#
#                          Brent    Bromley     Camden    Croydon     Ealing  \
# Index
# ID                   E09000005  E09000006  E09000007  E09000008  E09000009
# 1995-01-01 00:00:00    71306.6    81671.5     120933    69158.2    79885.9
# 1995-02-01 00:00:00    72022.3    81657.6     119509    68951.1    80897.1
# 1995-03-01 00:00:00    72015.8    81449.3     120282    68712.4    81379.9
# 1995-04-01 00:00:00    72965.6    81124.4     120098      68610    82188.9
# ...                        ...        ...        ...        ...        ...
# 2020-06-01 00:00:00     485388     426899     850884     370456     466309
# 2020-07-01 00:00:00     485619     430221     814615     375914     468656
# 2020-08-01 00:00:00     496606     439342     826732     375618     485527
# 2020-09-01 00:00:00     522546     444722     834938     381611     498874
# 2020-10-01 00:00:00     518636     451013     857205     385488     518392
#
#                        Enfield  ... NORTH WEST YORKS & THE HUMBER  \
# Index                           ...
# ID                   E09000010  ...  E12000002          E12000003
# 1995-01-01 00:00:00    72514.7  ...    43958.5            44803.4
# 1995-02-01 00:00:00    73155.2  ...    43925.4            44528.8
# 1995-03-01 00:00:00    72190.4  ...    44434.9            45200.5
# 1995-04-01 00:00:00    71442.9  ...    44267.8            45614.3
# ...                        ...  ...        ...                ...
# 2020-06-01 00:00:00     385629  ...     169091             168421
# 2020-07-01 00:00:00     387538  ...     171624             169181
# 2020-08-01 00:00:00     396986  ...     174483             172266
# 2020-09-01 00:00:00     400933  ...     175602             173032
# 2020-10-01 00:00:00     403170  ...     177796             177115
#
#                     EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# Index
# ID                      E12000004     E12000005       E12000006  E12000007
# 1995-01-01 00:00:00       45544.5       48527.5         56701.6    74435.8
# 1995-02-01 00:00:00       46051.6       49341.3         56593.6    72777.9
# 1995-03-01 00:00:00       45383.8       49442.2         56171.2    73896.8
# 1995-04-01 00:00:00       46124.2       49455.9         56567.9    74455.3
# ...                           ...           ...             ...        ...
# 2020-06-01 00:00:00        199121        202478          291767     478038
# 2020-07-01 00:00:00        201103        204203          293858     484709
# 2020-08-01 00:00:00        202542        205878          297786     492084
# 2020-09-01 00:00:00        203638        208714          303355     496736
# 2020-10-01 00:00:00        207605        210637          300744     490936
#
#                     SOUTH EAST SOUTH WEST Unnamed: 47    England
# Index
# ID                   E12000008  E12000009         NaN  E92000001
# 1995-01-01 00:00:00    64018.9    54705.2         NaN    53202.8
# 1995-02-01 00:00:00      63715    54356.1         NaN    53096.2
# 1995-03-01 00:00:00    64113.6    53583.1         NaN    53201.3
# 1995-04-01 00:00:00    64623.2      54786         NaN    53590.9
# ...                        ...        ...         ...        ...
# 2020-06-01 00:00:00     322662     259599         NaN     249298
# 2020-07-01 00:00:00     326941     265373         NaN     250179
# 2020-08-01 00:00:00     331706     266429         NaN     252875
# 2020-09-01 00:00:00     336074     273163         NaN     256774
# 2020-10-01 00:00:00     337412     274319         NaN     259159
#
# [311 rows x 48 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
#transpose
df2= df1.transpose()
df2.head(10)
# Out:
# Index                      ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# City of London      E09000001               91449             82202.8
# Barking & Dagenham  E09000002             50460.2             51085.8
# Barnet              E09000003             93284.5             93190.2
# Bexley              E09000004             64958.1             64787.9
# Brent               E09000005             71306.6             72022.3
# Bromley             E09000006             81671.5             81657.6
# Camden              E09000007              120933              119509
# Croydon             E09000008             69158.2             68951.1
# Ealing              E09000009             79885.9             80897.1
# Enfield             E09000010             72514.7             73155.2
#
# Index              1995-03-01 00:00:00 1995-04-01 00:00:00  \
# City of London                 79120.7             77101.2
# Barking & Dagenham               51269             53133.5
# Barnet                         92247.5             90762.9
# Bexley                         64367.5             64277.7
# Brent                          72015.8             72965.6
# Bromley                        81449.3             81124.4
# Camden                          120282              120098
# Croydon                        68712.4               68610
# Ealing                         81379.9             82188.9
# Enfield                        72190.4             71442.9
#
# Index              1995-05-01 00:00:00 1995-06-01 00:00:00  \
# City of London                 84409.1             94900.5
# Barking & Dagenham             53042.2             53700.3
# Barnet                           90258             90107.2
# Bexley                         63997.1             64252.3
# Brent                            73704             74310.5
# Bromley                        81542.6             82382.8
# Camden                          119929              121887
# Croydon                        68844.9             69052.5
# Ealing                         82077.1             81630.7
# Enfield                        70630.8             71348.3
#
# Index              1995-07-01 00:00:00 1995-08-01 00:00:00  \
# City of London                  110128              112329
# Barking & Dagenham             52113.1             52232.2
# Barnet                         91441.2             92361.3
# Bexley                         63722.7             64432.6
# Brent                            74127               73547
# Bromley                        82898.5             82054.4
# Camden                          124028              125530
# Croydon                        69142.5             68993.4
# Ealing                         82352.2             82706.7
# Enfield                        71837.5             72237.9
#
# Index              1995-09-01 00:00:00  ... 2020-01-01 00:00:00  \
# City of London                  104473  ...              773679
# Barking & Dagenham             51471.6  ...              303054
# Barnet                         93273.1  ...              521612
# Bexley                         64509.5  ...              336863
# Brent                          73789.5  ...              428436
# Bromley                        81440.4  ...              435090
# Camden                          120597  ...              828713
# Croydon                        69393.5  ...              372230
# Ealing                         82011.1  ...              469324
# Enfield                        71725.2  ...              389245
#
# Index              2020-02-01 00:00:00 2020-03-01 00:00:00  \
# City of London                  792769              828658
# Barking & Dagenham              302748              301570
# Barnet                          516411              522770
# Bexley                          338817              339095
# Brent                           469962              465941
# Bromley                         435392              433544
# Camden                          821595              852239
# Croydon                         372715              370346
# Ealing                          468630              480946
# Enfield                         388562              391735
#
# Index              2020-04-01 00:00:00 2020-05-01 00:00:00  \
# City of London                  900126              904803
# Barking & Dagenham              293553              292478
# Barnet                          529115              527494
# Bexley                          341997              338857
# Brent                           469583              481570
# Bromley                         435345              426143
# Camden                          863140              863897
# Croydon                         368793              370774
# Ealing                          481333              476675
# Enfield                         394040              392123
#
# Index              2020-06-01 00:00:00 2020-07-01 00:00:00  \
# City of London                  869929              785001
# Barking & Dagenham              299074              303701
# Barnet                          517266              521528
# Bexley                          340723              343385
# Brent                           485388              485619
# Bromley                         426899              430221
# Camden                          850884              814615
# Croydon                         370456              375914
# Ealing                          466309              468656
# Enfield                         385629              387538
#
# Index              2020-08-01 00:00:00 2020-09-01 00:00:00 2020-10-01 00:00:00
# City of London                  794881              768714              721490
# Barking & Dagenham              304696              301170              308583
# Barnet                          525762              535663              536263
# Bexley                          348046              345461              344254
# Brent                           496606              522546              518636
# Bromley                         439342              444722              451013
# Camden                          826732              834938              857205
# Croydon                         375618              381611              385488
# Ealing                          485527              498874              518392
# Enfield                         396986              400933              403170
#
# [10 rows x 311 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
df3=df2.reset_index()

# %%
df3.rename(columns={'index': 'Borough'}, inplace=True)
df3.set_index('Borough', inplace=True)
print(df3)
# Out:
# Index                        ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# Borough
# City of London        E09000001               91449             82202.8
# Barking & Dagenham    E09000002             50460.2             51085.8
# Barnet                E09000003             93284.5             93190.2
# Bexley                E09000004             64958.1             64787.9
# Brent                 E09000005             71306.6             72022.3
# Bromley               E09000006             81671.5             81657.6
# Camden                E09000007              120933              119509
# Croydon               E09000008             69158.2             68951.1
# Ealing                E09000009             79885.9             80897.1
# Enfield               E09000010             72514.7             73155.2
# Greenwich             E09000011             62300.1             60993.3
# Hackney               E09000012             61296.5             63187.1
# Hammersmith & Fulham  E09000013              124903              122088
# Haringey              E09000014             76287.6             78901.2
# Harrow                E09000015             84769.5             83396.1
# Havering              E09000016             68000.1             69393.5
# Hillingdon            E09000017             73834.8             75031.1
# Hounslow              E09000018             72231.7             71051.6
# Islington             E09000019             92516.5             94342.4
# Kensington & Chelsea  E09000020              182695              182345
# Kingston upon Thames  E09000021             80875.8             81230.1
# Lambeth               E09000022               67771             65381.5
# Lewisham              E09000023             60491.3             60869.3
# Merton                E09000024             82070.6             79982.7
# Newham                E09000025             53539.3             53153.9
# Redbridge             E09000026             72189.6             72141.6
# Richmond upon Thames  E09000027              109326              111103
# Southwark             E09000028             67885.2             64799.1
# Sutton                E09000029               71537             70893.2
# Tower Hamlets         E09000030             59865.2             62318.5
# Waltham Forest        E09000031             61319.4             60252.1
# Wandsworth            E09000032               88559               88641
# Westminster           E09000033              133025              131468
# Unnamed: 34                 NaN                 NaN                 NaN
# Inner London          E13000001               78252             75885.7
# Outer London          E13000002             72958.8             72937.9
# Unnamed: 37                 NaN                 NaN                 NaN
# NORTH EAST            E12000001             42076.4               42572
# NORTH WEST            E12000002             43958.5             43925.4
# YORKS & THE HUMBER    E12000003             44803.4             44528.8
# EAST MIDLANDS         E12000004             45544.5             46051.6
# WEST MIDLANDS         E12000005             48527.5             49341.3
# EAST OF ENGLAND       E12000006             56701.6             56593.6
# LONDON                E12000007             74435.8             72777.9
# SOUTH EAST            E12000008             64018.9               63715
# SOUTH WEST            E12000009             54705.2             54356.1
# Unnamed: 47                 NaN                 NaN                 NaN
# England               E92000001             53202.8             53096.2
#
# Index                1995-03-01 00:00:00 1995-04-01 00:00:00  \
# Borough
# City of London                   79120.7             77101.2
# Barking & Dagenham                 51269             53133.5
# Barnet                           92247.5             90762.9
# Bexley                           64367.5             64277.7
# Brent                            72015.8             72965.6
# Bromley                          81449.3             81124.4
# Camden                            120282              120098
# Croydon                          68712.4               68610
# Ealing                           81379.9             82188.9
# Enfield                          72190.4             71442.9
# Greenwich                        61377.8             61927.7
# Hackney                          63593.3             65139.6
# Hammersmith & Fulham              120636              121425
# Haringey                         78521.9             79545.6
# Harrow                           83416.2             83567.9
# Havering                           69368             69444.3
# Hillingdon                       74188.7             73911.4
# Hounslow                           72098             71890.3
# Islington                        93465.9             93344.5
# Kensington & Chelsea              182879              184177
# Kingston upon Thames             81111.5             81672.8
# Lambeth                          66336.5             66388.8
# Lewisham                           60288               59471
# Merton                           80661.7             79990.5
# Newham                           53458.3             54479.8
# Redbridge                        72501.4             72228.6
# Richmond upon Thames              107325              106875
# Southwark                        65763.3             63073.6
# Sutton                           70306.8             69411.9
# Tower Hamlets                    63938.7             66233.2
# Waltham Forest                   60871.1             60971.4
# Wandsworth                       87124.8               87026
# Westminster                       132260              133370
# Unnamed: 34                          NaN                 NaN
# Inner London                     76591.6             76851.6
# Outer London                     72714.5             72591.9
# Unnamed: 37                          NaN                 NaN
# NORTH EAST                       42369.7             42095.8
# NORTH WEST                       44434.9             44267.8
# YORKS & THE HUMBER               45200.5             45614.3
# EAST MIDLANDS                    45383.8             46124.2
# WEST MIDLANDS                    49442.2             49455.9
# EAST OF ENGLAND                  56171.2             56567.9
# LONDON                           73896.8             74455.3
# SOUTH EAST                       64113.6             64623.2
# SOUTH WEST                       53583.1               54786
# Unnamed: 47                          NaN                 NaN
# England                          53201.3             53590.9
#
# Index                1995-05-01 00:00:00 1995-06-01 00:00:00  \
# Borough
# City of London                   84409.1             94900.5
# Barking & Dagenham               53042.2             53700.3
# Barnet                             90258             90107.2
# Bexley                           63997.1             64252.3
# Brent                              73704             74310.5
# Bromley                          81542.6             82382.8
# Camden                            119929              121887
# Croydon                          68844.9             69052.5
# Ealing                           82077.1             81630.7
# Enfield                          70630.8             71348.3
# Greenwich                          63513             64751.6
# Hackney                            66194             66921.2
# Hammersmith & Fulham              124434              126175
# Haringey                           79374             79956.4
# Harrow                           83853.7             84173.2
# Havering                         68534.5             68464.6
# Hillingdon                       73117.1               74005
# Hounslow                         72877.5             72331.1
# Islington                        94346.4             97428.9
# Kensington & Chelsea              191474              197266
# Kingston upon Thames             82123.5             82205.7
# Lambeth                          69035.1             68881.2
# Lewisham                         58551.4             58041.4
# Merton                             80874             80704.9
# Newham                             55804             56067.8
# Redbridge                        72366.6             72279.4
# Richmond upon Thames              107708              112865
# Southwark                        64420.5             64155.8
# Sutton                           69759.2             70125.2
# Tower Hamlets                    66432.9             66232.2
# Waltham Forest                   61494.2             61547.8
# Wandsworth                       86518.1             88114.3
# Westminster                       133911              134562
# Unnamed: 34                          NaN                 NaN
# Inner London                     79129.2             79969.2
# Outer London                       72753             73189.4
# Unnamed: 37                          NaN                 NaN
# NORTH EAST                       43266.5             42315.3
# NORTH WEST                       44223.6               44113
# YORKS & THE HUMBER                 44831             45392.6
# EAST MIDLANDS                      45878               45680
# WEST MIDLANDS                    50369.7             50100.4
# EAST OF ENGLAND                  56479.8             56288.9
# LONDON                             75432             75606.2
# SOUTH EAST                       64530.4               65511
# SOUTH WEST                       54698.8             54420.2
# Unnamed: 47                          NaN                 NaN
# England                          53678.2             53735.2
#
# Index                1995-07-01 00:00:00 1995-08-01 00:00:00  \
# Borough
# City of London                    110128              112329
# Barking & Dagenham               52113.1             52232.2
# Barnet                           91441.2             92361.3
# Bexley                           63722.7             64432.6
# Brent                              74127               73547
# Bromley                          82898.5             82054.4
# Camden                            124028              125530
# Croydon                          69142.5             68993.4
# Ealing                           82352.2             82706.7
# Enfield                          71837.5             72237.9
# Greenwich                        65486.3             65076.4
# Hackney                          68390.8             68096.8
# Hammersmith & Fulham              124382              123625
# Haringey                         80746.3             81217.7
# Harrow                           84226.7             84430.6
# Havering                         68680.8             69023.4
# Hillingdon                       74671.1             74967.9
# Hounslow                         73717.8             74479.9
# Islington                        98976.1             98951.2
# Kensington & Chelsea              197963              198037
# Kingston upon Thames             82525.8             83342.8
# Lambeth                          69608.7               68840
# Lewisham                         58126.4             58151.3
# Merton                           81055.9             80781.1
# Newham                           55458.3             54709.4
# Redbridge                        72880.8             73275.2
# Richmond upon Thames              114657              112320
# Southwark                        67024.7             65525.9
# Sutton                           70789.6             69958.4
# Tower Hamlets                    64692.2             63472.3
# Waltham Forest                   61933.5             61916.4
# Wandsworth                       89830.6             90560.7
# Westminster                       133450              136582
# Unnamed: 34                          NaN                 NaN
# Inner London                     80550.5             80597.6
# Outer London                     73665.9             73691.1
# Unnamed: 37                          NaN                 NaN
# NORTH EAST                       43287.7             41899.1
# NORTH WEST                       44109.6             44193.7
# YORKS & THE HUMBER                 45535             45111.5
# EAST MIDLANDS                    46037.7             45922.5
# WEST MIDLANDS                      49860             49598.5
# EAST OF ENGLAND                  57242.3             56732.4
# LONDON                           75984.2             75529.3
# SOUTH EAST                       65224.9             64851.6
# SOUTH WEST                       54265.9             54365.7
# Unnamed: 47                          NaN                 NaN
# England                          53900.6             53600.3
#
# Index                1995-09-01 00:00:00  ... 2020-01-01 00:00:00  \
# Borough                                   ...
# City of London                    104473  ...              773679
# Barking & Dagenham               51471.6  ...              303054
# Barnet                           93273.1  ...              521612
# Bexley                           64509.5  ...              336863
# Brent                            73789.5  ...              428436
# Bromley                          81440.4  ...              435090
# Camden                            120597  ...              828713
# Croydon                          69393.5  ...              372230
# Ealing                           82011.1  ...              469324
# Enfield                          71725.2  ...              389245
# Greenwich                        63996.8  ...              398299
# Hackney                          68752.5  ...              552061
# Hammersmith & Fulham              123094  ...              723312
# Haringey                         82142.9  ...              553119
# Harrow                             83607  ...              448104
# Havering                         68108.2  ...              361600
# Hillingdon                       73843.6  ...              406012
# Hounslow                         74426.7  ...              412828
# Islington                        99582.6  ...              663552
# Kensington & Chelsea              197048  ...         1.24743e+06
# Kingston upon Thames               85111  ...              490422
# Lambeth                          70155.8  ...              523715
# Lewisham                           58743  ...              409138
# Merton                           80824.7  ...              501305
# Newham                           54585.5  ...              365798
# Redbridge                          73204  ...              419793
# Richmond upon Thames              110425  ...              660422
# Southwark                          63467  ...              502328
# Sutton                           69937.4  ...              371251
# Tower Hamlets                    62177.6  ...              460993
# Waltham Forest                   61548.2  ...              443224
# Wandsworth                       91373.7  ...              605153
# Westminster                       135993  ...         1.01169e+06
# Unnamed: 34                          NaN  ...                 NaN
# Inner London                     80402.9  ...              578370
# Outer London                     73454.4  ...              423030
# Unnamed: 37                          NaN  ...                 NaN
# NORTH EAST                       41850.9  ...              127337
# NORTH WEST                       44088.1  ...              164606
# YORKS & THE HUMBER               44837.9  ...              164734
# EAST MIDLANDS                    45771.7  ...              195365
# WEST MIDLANDS                    49319.7  ...              201142
# EAST OF ENGLAND                  56259.3  ...              288702
# LONDON                           74940.8  ...              476632
# SOUTH EAST                       64352.5  ...              322252
# SOUTH WEST                         54244  ...              257639
# Unnamed: 47                          NaN  ...                 NaN
# England                          53309.2  ...              247649
#
# Index                2020-02-01 00:00:00 2020-03-01 00:00:00  \
# Borough
# City of London                    792769              828658
# Barking & Dagenham                302748              301570
# Barnet                            516411              522770
# Bexley                            338817              339095
# Brent                             469962              465941
# Bromley                           435392              433544
# Camden                            821595              852239
# Croydon                           372715              370346
# Ealing                            468630              480946
# Enfield                           388562              391735
# Greenwich                         398193              397263
# Hackney                           566021              577441
# Hammersmith & Fulham              738027              718906
# Haringey                          541002              546664
# Harrow                            451504              451311
# Havering                          364140              365178
# Hillingdon                        404385              409495
# Hounslow                          414209              411185
# Islington                         666411              647626
# Kensington & Chelsea         1.31409e+06         1.34298e+06
# Kingston upon Thames              487914              487107
# Lambeth                           520194              516709
# Lewisham                          412211              412265
# Merton                            502685              509706
# Newham                            373430              374598
# Redbridge                         417211              420312
# Richmond upon Thames              655140              655971
# Southwark                         494219              495690
# Sutton                            372622              373718
# Tower Hamlets                     473550              478002
# Waltham Forest                    436242              435709
# Wandsworth                        610824              610531
# Westminster                  1.01836e+06         1.00877e+06
# Unnamed: 34                          NaN                 NaN
# Inner London                      582786              584052
# Outer London                      424187              425403
# Unnamed: 37                          NaN                 NaN
# NORTH EAST                        127213              128451
# NORTH WEST                        164853              166509
# YORKS & THE HUMBER                164531              165487
# EAST MIDLANDS                     193268              196403
# WEST MIDLANDS                     198970              200015
# EAST OF ENGLAND                   288819              289075
# LONDON                            475368              482748
# SOUTH EAST                        318822              324063
# SOUTH WEST                        256659              260121
# Unnamed: 47                          NaN                 NaN
# England                           246640              250634
#
# Index                2020-04-01 00:00:00 2020-05-01 00:00:00  \
# Borough
# City of London                    900126              904803
# Barking & Dagenham                293553              292478
# Barnet                            529115              527494
# Bexley                            341997              338857
# Brent                             469583              481570
# Bromley                           435345              426143
# Camden                            863140              863897
# Croydon                           368793              370774
# Ealing                            481333              476675
# Enfield                           394040              392123
# Greenwich                         398232              394191
# Hackney                           576961              577491
# Hammersmith & Fulham              689430              661399
# Haringey                          546755              550282
# Harrow                            450451              441979
# Havering                          367496              366540
# Hillingdon                        403660              410204
# Hounslow                          402369              396838
# Islington                         638524              628646
# Kensington & Chelsea         1.35411e+06         1.34231e+06
# Kingston upon Thames              486945              484792
# Lambeth                           506445              511629
# Lewisham                          413783              419458
# Merton                            511249              515996
# Newham                            368576              371073
# Redbridge                         419805              419015
# Richmond upon Thames              664165              685709
# Southwark                         497221              515173
# Sutton                            375309              369246
# Tower Hamlets                     465167              455222
# Waltham Forest                    437132              441639
# Wandsworth                        610678              601848
# Westminster                  1.02327e+06              944395
# Unnamed: 34                          NaN                 NaN
# Inner London                      580316              576810
# Outer London                      425799              424847
# Unnamed: 37                          NaN                 NaN
# NORTH EAST                        122881              127015
# NORTH WEST                        163320              164226
# YORKS & THE HUMBER                159851              164925
# EAST MIDLANDS                     195883              195000
# WEST MIDLANDS                     195479              198594
# EAST OF ENGLAND                   290982              290033
# LONDON                            473948              470083
# SOUTH EAST                        325585              321852
# SOUTH WEST                        256531              255734
# Unnamed: 47                          NaN                 NaN
# England                           245938              246220
#
# Index                2020-06-01 00:00:00 2020-07-01 00:00:00  \
# Borough
# City of London                    869929              785001
# Barking & Dagenham                299074              303701
# Barnet                            517266              521528
# Bexley                            340723              343385
# Brent                             485388              485619
# Bromley                           426899              430221
# Camden                            850884              814615
# Croydon                           370456              375914
# Ealing                            466309              468656
# Enfield                           385629              387538
# Greenwich                         386840              386665
# Hackney                           569407              586889
# Hammersmith & Fulham              682750              719546
# Haringey                          545541              548786
# Harrow                            438843              446469
# Havering                          370841              375236
# Hillingdon                        405585              411528
# Hounslow                          396324              396801
# Islington                         643668              659397
# Kensington & Chelsea         1.28305e+06         1.31597e+06
# Kingston upon Thames              480281              487208
# Lambeth                           518868              535983
# Lewisham                          425098              423926
# Merton                            521692              522400
# Newham                            373949              378292
# Redbridge                         413724              416655
# Richmond upon Thames              699844              694521
# Southwark                         507396              506968
# Sutton                            369053              370943
# Tower Hamlets                     442068              445848
# Waltham Forest                    446692              445677
# Wandsworth                        588343              594035
# Westminster                       956855              916419
# Unnamed: 34                          NaN                 NaN
# Inner London                      574029              578908
# Outer London                      423842              426805
# Unnamed: 37                          NaN                 NaN
# NORTH EAST                        129200              131272
# NORTH WEST                        169091              171624
# YORKS & THE HUMBER                168421              169181
# EAST MIDLANDS                     199121              201103
# WEST MIDLANDS                     202478              204203
# EAST OF ENGLAND                   291767              293858
# LONDON                            478038              484709
# SOUTH EAST                        322662              326941
# SOUTH WEST                        259599              265373
# Unnamed: 47                          NaN                 NaN
# England                           249298              250179
#
# Index                2020-08-01 00:00:00 2020-09-01 00:00:00  \
# Borough
# City of London                    794881              768714
# Barking & Dagenham                304696              301170
# Barnet                            525762              535663
# Bexley                            348046              345461
# Brent                             496606              522546
# Bromley                           439342              444722
# Camden                            826732              834938
# Croydon                           375618              381611
# Ealing                            485527              498874
# Enfield                           396986              400933
# Greenwich                         389844              402314
# Hackney                           585433              607663
# Hammersmith & Fulham              740691              748041
# Haringey                          570028              571385
# Harrow                            455589              457591
# Havering                          376242              373289
# Hillingdon                        411414              414548
# Hounslow                          409465              415771
# Islington                         689048              704189
# Kensington & Chelsea         1.35325e+06         1.35578e+06
# Kingston upon Thames              499805              507430
# Lambeth                           539549              548789
# Lewisham                          423538              432243
# Merton                            527370              532169
# Newham                            379881              379748
# Redbridge                         421606              430934
# Richmond upon Thames              694353              695399
# Southwark                         502552              506807
# Sutton                            377985              383597
# Tower Hamlets                     452443              462753
# Waltham Forest                    452930              455482
# Wandsworth                        614721              633709
# Westminster                       971306              938658
# Unnamed: 34                          NaN                 NaN
# Inner London                      589531              597737
# Outer London                      432573              437848
# Unnamed: 37                          NaN                 NaN
# NORTH EAST                        132248              136659
# NORTH WEST                        174483              175602
# YORKS & THE HUMBER                172266              173032
# EAST MIDLANDS                     202542              203638
# WEST MIDLANDS                     205878              208714
# EAST OF ENGLAND                   297786              303355
# LONDON                            492084              496736
# SOUTH EAST                        331706              336074
# SOUTH WEST                        266429              273163
# Unnamed: 47                          NaN                 NaN
# England                           252875              256774
#
# Index                2020-10-01 00:00:00
# Borough
# City of London                    721490
# Barking & Dagenham                308583
# Barnet                            536263
# Bexley                            344254
# Brent                             518636
# Bromley                           451013
# Camden                            857205
# Croydon                           385488
# Ealing                            518392
# Enfield                           403170
# Greenwich                         406635
# Hackney                           569792
# Hammersmith & Fulham              716886
# Haringey                          577636
# Harrow                            459106
# Havering                          371260
# Hillingdon                        419162
# Hounslow                          427832
# Islington                         693372
# Kensington & Chelsea         1.30134e+06
# Kingston upon Thames              521343
# Lambeth                           536452
# Lewisham                          440519
# Merton                            561639
# Newham                            374954
# Redbridge                         429315
# Richmond upon Thames              692638
# Southwark                         512705
# Sutton                            385190
# Tower Hamlets                     470151
# Waltham Forest                    459387
# Wandsworth                        638185
# Westminster                       930164
# Unnamed: 34                          NaN
# Inner London                      594393
# Outer London                      442427
# Unnamed: 37                          NaN
# NORTH EAST                        136281
# NORTH WEST                        177796
# YORKS & THE HUMBER                177115
# EAST MIDLANDS                     207605
# WEST MIDLANDS                     210637
# EAST OF ENGLAND                   300744
# LONDON                            490936
# SOUTH EAST                        337412
# SOUTH WEST                        274319
# Unnamed: 47                          NaN
# England                           259159
#
# [48 rows x 311 columns]

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
#only keep 33 rows (acc to Wikipedia there are 33 Boroughs, not 32)
df4=df3.iloc[:33]
df4=df4.drop(columns='ID')
print(df4)
# Out:
# Index                1995-01-01 1995-02-01 1995-03-01 1995-04-01 1995-05-01  \
# Borough
# City of London            91449    82202.8    79120.7    77101.2    84409.1
# Barking & Dagenham      50460.2    51085.8      51269    53133.5    53042.2
# Barnet                  93284.5    93190.2    92247.5    90762.9      90258
# Bexley                  64958.1    64787.9    64367.5    64277.7    63997.1
# Brent                   71306.6    72022.3    72015.8    72965.6      73704
# Bromley                 81671.5    81657.6    81449.3    81124.4    81542.6
# Camden                   120933     119509     120282     120098     119929
# Croydon                 69158.2    68951.1    68712.4      68610    68844.9
# Ealing                  79885.9    80897.1    81379.9    82188.9    82077.1
# Enfield                 72514.7    73155.2    72190.4    71442.9    70630.8
# Greenwich               62300.1    60993.3    61377.8    61927.7      63513
# Hackney                 61296.5    63187.1    63593.3    65139.6      66194
# Hammersmith & Fulham     124903     122088     120636     121425     124434
# Haringey                76287.6    78901.2    78521.9    79545.6      79374
# Harrow                  84769.5    83396.1    83416.2    83567.9    83853.7
# Havering                68000.1    69393.5      69368    69444.3    68534.5
# Hillingdon              73834.8    75031.1    74188.7    73911.4    73117.1
# Hounslow                72231.7    71051.6      72098    71890.3    72877.5
# Islington               92516.5    94342.4    93465.9    93344.5    94346.4
# Kensington & Chelsea     182695     182345     182879     184177     191474
# Kingston upon Thames    80875.8    81230.1    81111.5    81672.8    82123.5
# Lambeth                   67771    65381.5    66336.5    66388.8    69035.1
# Lewisham                60491.3    60869.3      60288      59471    58551.4
# Merton                  82070.6    79982.7    80661.7    79990.5      80874
# Newham                  53539.3    53153.9    53458.3    54479.8      55804
# Redbridge               72189.6    72141.6    72501.4    72228.6    72366.6
# Richmond upon Thames     109326     111103     107325     106875     107708
# Southwark               67885.2    64799.1    65763.3    63073.6    64420.5
# Sutton                    71537    70893.2    70306.8    69411.9    69759.2
# Tower Hamlets           59865.2    62318.5    63938.7    66233.2    66432.9
# Waltham Forest          61319.4    60252.1    60871.1    60971.4    61494.2
# Wandsworth                88559      88641    87124.8      87026    86518.1
# Westminster              133025     131468     132260     133370     133911
#
# Index                1995-06-01 1995-07-01 1995-08-01 1995-09-01 1995-10-01  \
# Borough
# City of London          94900.5     110128     112329     104473     108038
# Barking & Dagenham      53700.3    52113.1    52232.2    51471.6    51513.8
# Barnet                  90107.2    91441.2    92361.3    93273.1    92567.4
# Bexley                  64252.3    63722.7    64432.6    64509.5    64529.9
# Brent                   74310.5      74127      73547    73789.5    73264.1
# Bromley                 82382.8    82898.5    82054.4    81440.4    81862.2
# Camden                   121887     124028     125530     120597     117458
# Croydon                 69052.5    69142.5    68993.4    69393.5    68934.6
# Ealing                  81630.7    82352.2    82706.7    82011.1    80522.7
# Enfield                 71348.3    71837.5    72237.9    71725.2    72349.1
# Greenwich               64751.6    65486.3    65076.4    63996.8    63405.3
# Hackney                 66921.2    68390.8    68096.8    68752.5    67619.7
# Hammersmith & Fulham     126175     124382     123625     123094     123443
# Haringey                79956.4    80746.3    81217.7    82142.9    81791.5
# Harrow                  84173.2    84226.7    84430.6      83607    82492.7
# Havering                68464.6    68680.8    69023.4    68108.2    67425.6
# Hillingdon                74005    74671.1    74967.9    73843.6    72992.5
# Hounslow                72331.1    73717.8    74479.9    74426.7    73643.1
# Islington               97428.9    98976.1    98951.2    99582.6    97580.4
# Kensington & Chelsea     197266     197963     198037     197048     200006
# Kingston upon Thames    82205.7    82525.8    83342.8      85111      85727
# Lambeth                 68881.2    69608.7      68840    70155.8    69616.2
# Lewisham                58041.4    58126.4    58151.3      58743    58073.1
# Merton                  80704.9    81055.9    80781.1    80824.7    79569.2
# Newham                  56067.8    55458.3    54709.4    54585.5    54789.6
# Redbridge               72279.4    72880.8    73275.2      73204    72917.5
# Richmond upon Thames     112865     114657     112320     110425     108407
# Southwark               64155.8    67024.7    65525.9      63467      60886
# Sutton                  70125.2    70789.6    69958.4    69937.4    69963.8
# Tower Hamlets           66232.2    64692.2    63472.3    62177.6    62066.5
# Waltham Forest          61547.8    61933.5    61916.4    61548.2    60572.6
# Wandsworth              88114.3    89830.6    90560.7    91373.7    90246.4
# Westminster              134562     133450     136582     135993     134513
#
# Index                 ...   2020-01-01   2020-02-01   2020-03-01   2020-04-01  \
# Borough               ...
# City of London        ...       773679       792769       828658       900126
# Barking & Dagenham    ...       303054       302748       301570       293553
# Barnet                ...       521612       516411       522770       529115
# Bexley                ...       336863       338817       339095       341997
# Brent                 ...       428436       469962       465941       469583
# Bromley               ...       435090       435392       433544       435345
# Camden                ...       828713       821595       852239       863140
# Croydon               ...       372230       372715       370346       368793
# Ealing                ...       469324       468630       480946       481333
# Enfield               ...       389245       388562       391735       394040
# Greenwich             ...       398299       398193       397263       398232
# Hackney               ...       552061       566021       577441       576961
# Hammersmith & Fulham  ...       723312       738027       718906       689430
# Haringey              ...       553119       541002       546664       546755
# Harrow                ...       448104       451504       451311       450451
# Havering              ...       361600       364140       365178       367496
# Hillingdon            ...       406012       404385       409495       403660
# Hounslow              ...       412828       414209       411185       402369
# Islington             ...       663552       666411       647626       638524
# Kensington & Chelsea  ...  1.24743e+06  1.31409e+06  1.34298e+06  1.35411e+06
# Kingston upon Thames  ...       490422       487914       487107       486945
# Lambeth               ...       523715       520194       516709       506445
# Lewisham              ...       409138       412211       412265       413783
# Merton                ...       501305       502685       509706       511249
# Newham                ...       365798       373430       374598       368576
# Redbridge             ...       419793       417211       420312       419805
# Richmond upon Thames  ...       660422       655140       655971       664165
# Southwark             ...       502328       494219       495690       497221
# Sutton                ...       371251       372622       373718       375309
# Tower Hamlets         ...       460993       473550       478002       465167
# Waltham Forest        ...       443224       436242       435709       437132
# Wandsworth            ...       605153       610824       610531       610678
# Westminster           ...  1.01169e+06  1.01836e+06  1.00877e+06  1.02327e+06
#
# Index                  2020-05-01   2020-06-01   2020-07-01   2020-08-01  \
# Borough
# City of London             904803       869929       785001       794881
# Barking & Dagenham         292478       299074       303701       304696
# Barnet                     527494       517266       521528       525762
# Bexley                     338857       340723       343385       348046
# Brent                      481570       485388       485619       496606
# Bromley                    426143       426899       430221       439342
# Camden                     863897       850884       814615       826732
# Croydon                    370774       370456       375914       375618
# Ealing                     476675       466309       468656       485527
# Enfield                    392123       385629       387538       396986
# Greenwich                  394191       386840       386665       389844
# Hackney                    577491       569407       586889       585433
# Hammersmith & Fulham       661399       682750       719546       740691
# Haringey                   550282       545541       548786       570028
# Harrow                     441979       438843       446469       455589
# Havering                   366540       370841       375236       376242
# Hillingdon                 410204       405585       411528       411414
# Hounslow                   396838       396324       396801       409465
# Islington                  628646       643668       659397       689048
# Kensington & Chelsea  1.34231e+06  1.28305e+06  1.31597e+06  1.35325e+06
# Kingston upon Thames       484792       480281       487208       499805
# Lambeth                    511629       518868       535983       539549
# Lewisham                   419458       425098       423926       423538
# Merton                     515996       521692       522400       527370
# Newham                     371073       373949       378292       379881
# Redbridge                  419015       413724       416655       421606
# Richmond upon Thames       685709       699844       694521       694353
# Southwark                  515173       507396       506968       502552
# Sutton                     369246       369053       370943       377985
# Tower Hamlets              455222       442068       445848       452443
# Waltham Forest             441639       446692       445677       452930
# Wandsworth                 601848       588343       594035       614721
# Westminster                944395       956855       916419       971306
#
# Index                  2020-09-01   2020-10-01
# Borough
# City of London             768714       721490
# Barking & Dagenham         301170       308583
# Barnet                     535663       536263
# Bexley                     345461       344254
# Brent                      522546       518636
# Bromley                    444722       451013
# Camden                     834938       857205
# Croydon                    381611       385488
# Ealing                     498874       518392
# Enfield                    400933       403170
# Greenwich                  402314       406635
# Hackney                    607663       569792
# Hammersmith & Fulham       748041       716886
# Haringey                   571385       577636
# Harrow                     457591       459106
# Havering                   373289       371260
# Hillingdon                 414548       419162
# Hounslow                   415771       427832
# Islington                  704189       693372
# Kensington & Chelsea  1.35578e+06  1.30134e+06
# Kingston upon Thames       507430       521343
# Lambeth                    548789       536452
# Lewisham                   432243       440519
# Merton                     532169       561639
# Newham                     379748       374954
# Redbridge                  430934       429315
# Richmond upon Thames       695399       692638
# Southwark                  506807       512705
# Sutton                     383597       385190
# Tower Hamlets              462753       470151
# Waltham Forest             455482       459387
# Wandsworth                 633709       638185
# Westminster                938658       930164
#
# [33 rows x 310 columns]

# %%
#Melt df
df4=df4.reset_index()
df5 =pd.melt(df4, id_vars=["Borough"], value_name="price")
df5.head()
# Out:
#               Borough      Index    price
# 0      City of London 1995-01-01    91449
# 1  Barking & Dagenham 1995-01-01  50460.2
# 2              Barnet 1995-01-01  93284.5
# 3              Bexley 1995-01-01  64958.1
# 4               Brent 1995-01-01  71306.6

# %%
df5.rename(columns={'Index': 'month'}, inplace=True)
df5.head()
# Out:
#               Borough      month    price
# 0      City of London 1995-01-01    91449
# 1  Barking & Dagenham 1995-01-01  50460.2
# 2              Barnet 1995-01-01  93284.5
# 3              Bexley 1995-01-01  64958.1
# 4               Brent 1995-01-01  71306.6

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
df5.price=df5.price.astype(float) 
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10230 entries, 0 to 10229
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Borough  10230 non-null  object
#  1   month    10230 non-null  datetime64[ns]
#  2   price    10230 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 239.9+ KB

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
print(df5['Borough'])
# Out:
# 0            City of London
# 1        Barking & Dagenham
# 2                    Barnet
# 3                    Bexley
# 4                     Brent
#                 ...
# 10225                Sutton
# 10226         Tower Hamlets
# 10227        Waltham Forest
# 10228            Wandsworth
# 10229           Westminster
# Name: Borough, Length: 10230, dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
camden = df5.loc[df5['Borough'] == "Camden"]
camden=camden.set_index('month')
camden=camden[['price']]
camden.plot(title="Monthly avg. housing prices for Camden")
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#extract year
year=lambda x: x.year
df5['year']=df5['month'].apply(year)
df6=df5.set_index('month')
df6.head()
# Out:
#                        Borough        price  year
# month
# 1995-01-01      City of London  91448.98487  1995
# 1995-01-01  Barking & Dagenham  50460.22660  1995
# 1995-01-01              Barnet  93284.51832  1995
# 1995-01-01              Bexley  64958.09036  1995
# 1995-01-01               Brent  71306.56698  1995

# %%
#make data yearly (it seems like the objective is to find the largest YEARLY price increase among the boroughs, even though not specified)
yearly = df6.groupby('Borough').resample('Y').mean()

# %%
#make keep only year 1995 and year 2020 to get difference
yearly9520=yearly.loc[(yearly['year'] == 1995) | (yearly['year'] == 2020) ]

# %%
#compute percentage change from 1995 to 2020 by borough

diff = yearly9520.groupby('Borough').pct_change().dropna()
diff=diff['price']
##This is the list of london boroughs sorted from highest to lowest percentage increase in housing prices between 1995 and 2020
diff.sort_values(ascending=False).head(3)
# Out:
# Borough         month
# Hackney         2020-12-31    7.737909
# City of London  2020-12-31    7.215219
# Southwark       2020-12-31    6.844779
# Name: price, dtype: float64

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
#drop unneccessary column (month)
yearly=yearly.reset_index()
yearly=yearly.set_index('year').drop(columns='month')

# %%
#create function
def create_price_ratio(borough):
    cond=yearly['Borough']==  borough
    filtered=yearly[cond].loc[[1998,2018],:]
    filtered.reset_index(inplace=True)
    diff = filtered['price'].pct_change().dropna() * 100
    return diff.iloc[0]

#test for Borough='Camden'
create_price_ratio('Camden')
# Out:
# 393.53534088842605

# %%
#make list of boroughs
London_Boroughs = list(yearly['Borough'].unique())

#loop over list and append to empty dict
boroughs_pct={}
for borough in London_Boroughs:
    pct_diff=create_price_ratio(borough)
    boroughs_pct.update({borough: pct_diff})

boroughs_pct=pd.DataFrame.from_dict(boroughs_pct, orient='index', columns=['pct_change'])
print(boroughs_pct)
# Out:
#                       pct_change
# Barking & Dagenham    389.661861
# Barnet                335.819592
# Bexley                324.897705
# Brent                 389.455450
# Bromley               309.478469
# Camden                393.535341
# City of London        430.162038
# Croydon               320.110028
# Ealing                331.145090
# Enfield               326.347158
# Greenwich             376.303635
# Hackney               519.828556
# Hammersmith & Fulham  313.779810
# Haringey              413.462496
# Harrow                305.919643
# Havering              332.523037
# Hillingdon            320.027308
# Hounslow              297.640911
# Islington             384.404801
# Kensington & Chelsea  408.246507
# Kingston upon Thames  327.054952
# Lambeth               395.775116
# Lewisham              444.922104
# Merton                374.127331
# Newham                430.539044
# Redbridge             347.118201
# Richmond upon Thames  300.516190
# Southwark             451.648530
# Sutton                311.852261
# Tower Hamlets         362.670104
# Waltham Forest        483.475581
# Wandsworth            375.770935
# Westminster           435.356539

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# -manipulated dataframe to get average housing prices for each of the 33 London Boroughs by year ranging from 1995 to 2020
# -since it was not specified in the task which time interval to look at, I calculated the percentage change of avg yearly housing price from 1995 to 2020 by borough
# #Top 3 are: Hackney: +780%, City of London: +737%, Soutchwark: +689%
